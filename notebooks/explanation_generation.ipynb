# %% [markdown]
# # Explanation Generation Example

# %% [markdown]
# This notebook will demonstrate explanation generation examples for reflection-oriented QA.

# %% [markdown]
# Suggested resource: https://www.teach-anything.com/
