# %% [markdown]
# # Adaptive Questioning Example

# %% [markdown]
# This notebook will demonstrate adaptive or Socratic questioning examples for HLQA.

# %% [markdown]
# Suggested resource: https://github.com/eth-nlped/socratic-generation
