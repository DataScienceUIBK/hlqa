# %% [markdown]
# # Hint Generation with HintEval

# %% [markdown]
# This notebook will demonstrate hint generation and evaluation examples.

# %% [markdown]
# Suggested resource: https://github.com/DataScienceUIBK/HintEval
